# %% [markdown]
# # matching user to course along subjects

# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans 
from sklearn.metrics import adjusted_rand_score 
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
# Reading my data in course-subjects, subject name, course-subjects-ratings and new user data 

course_features=pd.read_excel("subject_courses.xlsx")
subjects=pd.read_csv("subjects.csv")
stud_subjects = [89, "Mathematics","Chemistry","Financial Accounting"]
coursesub_ratings=pd.read_csv("coursesubject_rating.csv")
stud_scores = [89, 67, 52,45]

# %%
# making a matrix of course, subjects and weights 

#course_features.head()
#course_features.set_index("CourseName", inplace = True)
#course_names=course_features["CourseName"]
#course_names
#subjects.head()

#subjects.shape

course_sub=pd.DataFrame(0, index=course_features["CourseName"], columns=subjects["SubjectName"])

for index, row in coursesub_ratings.iterrows():
    course_sub.loc[row['Course'],row["Subject"]]=row["Rating"]

#course_sub

# %%
course_sub.tail()
#course_sub.shape
# Out:
# SubjectName                         Agricultural Science  \
# CourseName
# Computer Science                                       8
# Building Engineering                                   0
# Accounting                                             0
# Medicine                                               9
# Management and Information Science                     0
#
# SubjectName                         Air Conditioning and Refrigeration  \
# CourseName
# Computer Science                                                     0
# Building Engineering                                                 0
# Accounting                                                           0
# Medicine                                                             0
# Management and Information Science                                   0
#
# SubjectName                         Animal Husbandry   Applied Electricity  \
# CourseName
# Computer Science                                    0                    0
# ...

# %%
# normalizing my incoming student data into a series of best subjects and weights on a 5point scale

#stud_subjects = [89, "Mathematics","Chemistry","Financial Accounting"]
#stud_scores = [89, 67, 52,45]
#stud_scores_series = pd.Series(stud_scores[1:], index=stud_subjects[1:],dtype=np.float64, name="User")
#stud_scores_norm=(stud_scores_series/100)*5
#stud_scores_norm.name
#course_sub=course_sub.append(stud_scores_norm, sort=False)
#course_sub.drop(course_sub.index[-1], inplace=True)
#course_sub.fillna(0, axis=0, inplace=True)
course_sub.loc["User"]["English Language"]
# Out:
# 0.0

# %%
# Clustering using KMeans 

k_num=3
model=KMeans(n_clusters=k_num, init="k-means++", n_init=10, max_iter=100)
model.fit(course_sub)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#prediction = model.predict(course_sub)
#stud_scores_norm.shape
plt.scatter(course_sub[:,0], course_sub[:,1], c= prediction, s=50,cmap='viridis')
centers=model.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha = 0.5)

# %%
#model.cluster_centers_
model.labels_["User"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-d94326d05c94> in <module>
#       1 #model.cluster_centers_
# ----> 2 model.labels_["User"]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
