# %%
import pandas as pdhttps://stackoverflow.com/questions/47074894/how-to-calculate-correlation-between-rows-in-python-pandas-data-frame
https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corrwith.html#pandas.DataFrame.corrwith

# %%
user_feat=pd.read_excel("users_features.xlsx")

# %%
user_feat.dtypes
# Out:
# Users ID          int64
# best subject1    object
# best subject2    object
# best subject3    object
# dtype: object

# %%
stud = [89, "Mathematics","Commerce","Financial Accounting"]

# %%
new_user=pd.DataFrame( data=[stud], 
                       columns= ['Users ID', "best subject1","best subject2","best subject3"])
new_user
# Out:
#    Users ID best subject1 best subject2         best subject3
# 0        89   Mathematics      Commerce  Financial Accounting

# %%
user_feat.corrwith(new_user.iloc[0], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-7757a57c27ce> in <module>
# ----> 1 user_feat.corrwith(new_user.iloc[0], axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in corrwith(self, other, axis, drop)
#    6668
#    6669         if isinstance(other, Series):
# -> 6670             return this.apply(other.corr, axis=axis)
#    6671
#    6672         other = other._get_numeric_data()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# ...

# %%
user_feat.append(new_user)
# Out:
#     Users ID         best subject1         best subject2         best subject3
# 0        101              Commerce           Mathematics               Physics
# 1        102               Biology           Mathematics      English Language
# 2        103  Agricultural Science      English Language             Chemistry
# 3        104               Physics  Financial Accounting              Commerce
# 4        105  Financial Accounting           Mathematics              Commerce
# 5        106           Mathematics      English Language  Agricultural Science
# 6        107               Biology           Mathematics             Chemistry
# 7        108               Physics      English Language             Chemistry
# 8        109           Mathematics  Financial Accounting      English Language
# 9        110               Biology             Chemistry           Mathematics
# 10       111       Civic Education              Commerce      English Language
# ...

# %%
user_feat[0:1]
# Out:
#    Users ID best subject1 best subject2 best subject3
# 0       101      Commerce   Mathematics       Physics
